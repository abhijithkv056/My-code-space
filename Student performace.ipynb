# %%
import pandas as pd

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df['gender'].describe()
# Out:
# count       1000
# unique         2
# top       female
# freq         518
# Name: gender, dtype: object

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
gp1 = df.groupby('race/ethnicity')
gp1.first()
# Out:
#                 gender parental level of education         lunch  \
# race/ethnicity
# group A           male          associate's degree  free/reduced
# group B         female           bachelor's degree      standard
# group C         female                some college      standard
# group D           male                 high school  free/reduced
# group E         female             master's degree  free/reduced
#
#                test preparation course  math score  reading score  \
# race/ethnicity
# group A                           none          47             57
# group B                           none          72             72
# group C                      completed          69             90
# group D                      completed          64             64
# group E                           none          56             72
#
#                 writing score
# race/ethnicity
# group A                    44
# group B                    74
# group C                    88
# ...

# %%
gp1.get_group('group A')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 13     male        group A                some college      standard
# 14   female        group A             master's degree      standard
# 25     male        group A             master's degree  free/reduced
# 46   female        group A          associate's degree      standard
# ..      ...            ...                         ...           ...
# 974  female        group A                some college      standard
# 983  female        group A                some college      standard
# 985    male        group A                 high school      standard
# 988  female        group A            some high school  free/reduced
# 994    male        group A                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
gp1_alt = df[df['race/ethnicity']=='group A']
gp1_alt.head(20)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 13     male        group A                some college      standard
# 14   female        group A             master's degree      standard
# 25     male        group A             master's degree  free/reduced
# 46   female        group A          associate's degree      standard
# 61     male        group A            some high school  free/reduced
# 62     male        group A          associate's degree  free/reduced
# 72   female        group A          associate's degree  free/reduced
# 77     male        group A           bachelor's degree      standard
# 82     male        group A                some college  free/reduced
# 88   female        group A                some college      standard
# 112    male        group A          associate's degree      standard
# 129  female        group A           bachelor's degree      standard
# ...

# %%
gp1_alt['parental level of education'].value_counts()
# Out:
# some high school      24
# some college          18
# high school           18
# associate's degree    14
# bachelor's degree     12
# master's degree        3
# Name: parental level of education, dtype: int64

# %%
df['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
df['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
import seaborn as sns

# %%
plot_data = df.iloc[:,5:]
i = plot_data

# %%
sns.lineplot(data=i, x='reading score', y='writing score')
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='writing score'>

# %%
sns.scatterplot(data=df.head(100), x='reading score', y='writing score',hue='race/ethnicity')
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='writing score'>

# %%
sns.scatterplot(data=i, x='reading score', y='writing score')
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='writing score'>

# %%
sns.scatterplot(data=i, x='reading score', y='math score')
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='math score'>

# %%
sns.scatterplot(data=i, x='writing score', y='math score')
# Out:
# <AxesSubplot:xlabel='writing score', ylabel='math score'>

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19392\2522776102.py in <module>
# ----> 1 pvt = df.pivot("math score","parental level of education",)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    7883         from pandas.core.reshape.pivot import pivot
#    7884
# -> 7885         return pivot(self, index=index, columns=columns, values=values)
#    7886
#    7887     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     518         else:
#     519             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520     return indexed.unstack(columns_listlike)
#     521
#     522
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in unstack(self, level, fill_value)
# ...

# %%
df2 = df.loc[:,['parental level of education','math score','reading score','writing score']]
df1 = df2.groupby('parental level of education').mean()

# %%
df1.sort_values(by='math score',ascending=False)
# Out:
#                              math score  reading score  writing score
# parental level of education
# master's degree               69.745763      75.372881      75.677966
# bachelor's degree             69.389831      73.000000      73.381356
# associate's degree            67.882883      70.927928      69.896396
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268
# high school                   62.137755      64.704082      62.448980

# %%
df1
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
df2
# Out:
#     parental level of education  math score  reading score  writing score
# 0             bachelor's degree          72             72             74
# 1                  some college          69             90             88
# 2               master's degree          90             95             93
# 3            associate's degree          47             57             44
# 4                  some college          76             78             75
# ..                          ...         ...            ...            ...
# 995             master's degree          88             99             95
# 996                 high school          62             55             55
# 997                 high school          59             71             65
# 998                some college          68             78             77
# 999                some college          77             86             86
#
# [1000 rows x 4 columns]

# %%
df3 = sns.histplot(data=df2['math score'])

# %%
sns.jointplot(x=df2['reading score'], y=df2['writing score'], kind="kde")

# %%
sns.heatmap(data=df1, annot=True)
# Out:
# <AxesSubplot:ylabel='parental level of education'>

# %%
dnine = 43
dside = 65
print(dnine+dside)
# Out:
# 108

# %%
esum = 32
